# %%
import os
from dotenv import load_dotenv
load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
OPENROUTER_API_KEY = os.getenv("OPENROUTER_API_KEY")
OPENROUTER_BASE_URL = os.getenv("OPENROUTER_BASE_URL")

# %%
from langchain.chat_models import init_chat_model

# %%
model = init_chat_model(
    "openrouter/free",
    model_provider="openai",
    api_key=OPENROUTER_API_KEY,
    base_url=OPENROUTER_BASE_URL,
    temperature=0.7,
    max_tokens=1024
)

# %%
response = model.invoke("Compare GB vs PB vs TB in terms of data!")

# %%
response.content
# Out:
# "GB, PB, and TB are all **data storage technologies**, but they differ significantly in terms of **capacity**, **data transfer rate**, **speed**, and **use cases**. Here's a breakdown of each in terms of data:\n\n---\n\n### 🔹 **GB (Gigabyte)**\n- **Definition**: 1 gigabyte = 1,073,741,824 bytes.\n- **Data Capacity**: A single GB is a **fixed unit**, typically used to describe **storage capacity**.\n- **Example**: A 1 GB hard drive or SSD can store up to 1 GB of data.\n- **Use Case**: Measured in **storage size**.\n\n---\n\n### 🔹 **PB (Petabyte)**\n- **Definition**: 1 petabyte = 1 petabyte = 1,000,000,000,000 bytes.\n- **Data Capacity**: A **very large unit** used to describe **massive storage**, such as cloud storage or data centers.\n- **Example**: A 1 PB storage device could hold up to 1,000 TB of data.\n- **Use Case**: Used in **data center and cloud storage**.\n\n---\n\n### 🔹 **TB (Terabyte)**\n- **Definition**: 1 terabyte = 1,000 gigabytes.\n- **Data Capacity**: A **common unit*
# ...

# %%
groq_model = init_chat_model("groq:llama-3.1-8b-instant")

# %%
response = groq_model.invoke("Delinate the differences between database, data warehouse and data lakes.")

# %%
response.content
# Out:
# 'Database, data warehouse, and data lakes are all used for storing and managing data, but they serve different purposes and have distinct characteristics. Here are the main differences between them:\n\n**1. Database:**\nA database is a collection of organized data that is stored in a structured format, typically in a relational database management system (RDBMS) like MySQL or Oracle. Databases are designed to support high-performance transactions, data integrity, and ACID (Atomicity, Consistency, Isolation, Durability) compliance.\n\n**Key characteristics:**\n\n- Structured data\n- Organized schema\n- Data is normalized for efficient storage and querying\n- Supports transactions and ACID compliance\n- Typically used for transactional and operational data\n\n**2. Data Warehouse:**\nA data warehouse is a centralized repository that stores integrated data from various sources in a structured format, primarily for analysis and reporting purposes. Data warehouses are designed to support b
# ...
